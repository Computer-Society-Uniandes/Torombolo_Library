# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# class Perceptron: # simplificado
#     def __init__(self, input_size):
#         self.weights = np.random.rand(input_size)
#         self.bias = np.random.rand()

#     def activation(self, x):
#         return 1 if x >= 0 else 0
    
#     def predict(self, inputs):
#         weighted_sum = np.dot(inputs, self.weights) + self.bias
#         return self.activation(weighted_sum)

import sys
import os

# Obtén la ruta del directorio padre (el directorio raíz de tu proyecto)
parent_dir = os.path.abspath(os.path.join(os.path.dirname(__name__), '../..'))
sys.path.append(parent_dir)

from torombolo.perceptron import Perceptron

# %%
input_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels = np.array([0, 0, 0, 1])

# %%
colors = ['red' if label == 0 else 'green' for label in labels]

plt.figure(figsize = (7, 4))

plt.scatter( x = input_data[:, 0], y = input_data[:, 1], c = colors, alpha = .7, s=70)

plt.title('Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True, linestyle='--', linewidth=0.4)
plt.show()

# %%
epochs = 100000
learning_rate = 0.1

perceptron = Perceptron(learning_rate=learning_rate, n_iter=epochs)

# %%
perceptron.fit(input_data, labels)
print('Accuracy: ', perceptron.score(input_data, labels))
print('Pesos: ', perceptron.w_)
print('Bias: ', perceptron.b_)
# Out:
# Accuracy:  1.0
# Pesos:  [0.4724338  0.35475884]
# Bias:  [-0.53727371]

# %%
test_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels = np.array([0, 0, 0, 1])

predictions = perceptron.predict(test_data)
predictions
# Out:
# array([0, 0, 0, 1])

# %%
decision_line_slope = -perceptron.w_[0] / perceptron.w_[1]
decision_line_intercept = -perceptron.b_ / perceptron.w_[1]

# Crear puntos para trazar la línea de decisión
x_values = np.linspace(-0.5, 1.5, 100)
y_values = decision_line_slope * x_values + decision_line_intercept

# %%
plt.figure(figsize=(7,  4))

plt.scatter(input_data[:, 0], input_data[:, 1], c=colors, marker='o', alpha=.7, s=90)
plt.plot(x_values, y_values, color='blue', linewidth=1.5, label='Decision Boundary', alpha=0.7)

plt.title('Perceptron Decision Boundary for AND Operation')
plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)
plt.axhline(0, color='black', linewidth=0.6)
plt.axvline(0, color='black', linewidth=0.6)
plt.grid(True, linestyle='--', linewidth=0.4)
plt.show()
